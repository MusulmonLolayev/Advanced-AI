# %% [markdown]
# # Assignment 3 Submission Helper
#
# Use `bash collectSubmission.sh` to create the final zip bundle after you complete the notebook and task files.

# %%
print('Run: bash collectSubmission.sh')
