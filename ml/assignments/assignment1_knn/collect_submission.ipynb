# %% [markdown]
# # Collect Submission
#
# Run this notebook after you finish `knn.ipynb`.
#
# It creates a zip archive of the starter package, notebooks, and driver scripts.

# %%
# !bash collectSubmission.sh
