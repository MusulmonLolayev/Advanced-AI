# %% [markdown]
# # Collect Submission
#
# This notebook is the submission instruction file.
#
# Use it only after you finish `knn.ipynb` and confirm that your self-checks and required task runs work.
#
# What gets packaged:
# - `advanced_ai/`
# - `knn.ipynb`
# - `collect_submission.ipynb`
# - required and optional task driver scripts
# - `requirements.txt`
# - `results/`
#
# Command-line alternative:
#
# ```bash
# bash collectSubmission.sh
# ```
#
# Output:
# - `assignment1_knn_submission.zip`

# %%
# !bash collectSubmission.sh
