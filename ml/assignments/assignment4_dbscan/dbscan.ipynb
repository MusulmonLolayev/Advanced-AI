# %% [markdown]
# # Lab 4: DBSCAN
#
# Work through the cells in order. The implementation lives in `advanced_ai/clustering/dbscan.py` and uses NumPy only for the core algorithm.

# %% [markdown]
# ## Step 1: Notation
#
# - $X = \{x_1,\dots,x_n\}$
# - $N_\varepsilon(x_i) = \{x_j : \|x_j - x_i\|_2 \le \varepsilon\}$
# - core, border, and noise as defined in the lecture

# %%
from advanced_ai.config import *
from advanced_ai.task_utils import require_file
from advanced_ai.data_utils import load_toy_bundle
from advanced_ai.clustering.dbscan import DBSCANClustering

print('Imports ready.')

# %% [markdown]
# ## Step 2: Implement the core algorithm
#
# Complete `DBSCANClustering._expand_cluster` and `DBSCANClustering.fit`.
#
# Use `min_pts` in code, which matches `MinPts` in the lecture.

# %% [markdown]
# ## Step 3: Run self-checks
#
# After implementing DBSCAN, run:
#
# ```python
# from advanced_ai.self_checks import run_all_checks
# run_all_checks()
# ```

# %% [markdown]
# ## Step 4: Toy dataset
#
# Run `python toy_dbscan.py` and inspect the saved plot and printed cluster summary.

# %% [markdown]
# ## Step 5: Iris data
#
# Run `python iris_dbscan.py` and compare raw versus standardized features.

# %% [markdown]
# ## Step 6: Scaling and outliers
#
# Run `python scaling_and_outliers.py` and explain the results in your own words.
