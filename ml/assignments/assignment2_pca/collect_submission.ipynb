# %% [markdown]
# # Collect PCA Submission
#
# Run the packaging script after the checks pass.
#
# The main worksheet is `pca.ipynb`.
# The submission archive will be `assignment2_pca_submission.zip`.
#
# ```bash
# bash collectSubmission.sh
# ```

# %%
# !bash collectSubmission.sh
